# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv("Student_performance_data_modify1.csv")
df
# Out:
#       Absences       GPA
# 0            7  2.929196
# 1            0  3.042915
# 2           26  0.112602
# 3           14  2.054218
# 4           17  1.288061
# ...        ...       ...
# 2387         2  3.455509
# 2388         4  3.279150
# 2389        20  1.142333
# 2390        17  1.803297
# 2391        13  2.140014
#
# [2392 rows x 2 columns]

# %%
plt.scatter(df['Absences'],df['GPA'],color='r')
plt.xlabel('Absences')
plt.ylabel('GPA')
# Out:
# Text(0, 0.5, 'GPA')

# %%
X=df.iloc[:,0:1]
y=df.iloc[:,-1]

# %%
y
# Out:
# 0       2.929196
# 1       3.042915
# 2       0.112602
# 3       2.054218
# 4       1.288061
#           ...
# 2387    3.455509
# 2388    3.279150
# 2389    1.142333
# 2390    1.803297
# 2391    2.140014
# Name: GPA, Length: 2392, dtype: float64

# %%
X
# Out:
#       Absences
# 0            7
# 1            0
# 2           26
# 3           14
# 4           17
# ...        ...
# 2387         2
# 2388         4
# 2389        20
# 2390        17
# 2391        13
#
# [2392 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=44)

# %%
from sklearn.linear_model import LinearRegression

# %% [raw]
# lr=Linearregression

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_train
# Out:
#       Absences
# 1163         7
# 1771        18
# 2243        15
# 1539         9
# 2252        20
# ...        ...
# 84          12
# 2144        17
# 571         12
# 1197        19
# 1812        10
#
# [1913 rows x 1 columns]

# %%
y_train
# Out:
# 1163    2.952722
# 1771    1.820920
# 2243    2.192415
# 1539    2.761824
# 2252    1.162574
#           ...
# 84      2.342837
# 2144    1.526960
# 571     2.119171
# 1197    1.812887
# 1812    2.672755
# Name: GPA, Length: 1913, dtype: float64

# %%
X_test
# Out:
#       Absences
# 656         24
# 854          9
# 2121        23
# 1727        15
# 585         24
# ...        ...
# 1872        11
# 495         24
# 1831        19
# 223          3
# 2363         9
#
# [479 rows x 1 columns]

# %%
y_test
# Out:
# 656     0.499988
# 854     2.251754
# 2121    1.268772
# 1727    1.488705
# 585     0.184251
#           ...
# 1872    2.278952
# 495     1.291230
# 1831    1.494870
# 223     2.621623
# 2363    2.669979
# Name: GPA, Length: 479, dtype: float64

# %%
y_predict=lr.predict(X_test)

# %%
plt.scatter(df['Absences'],df['GPA'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('Absences')
plt.ylabel('GPA')
# Out:
# Text(0, 0.5, 'GPA')

# %%
m = lr.coef_
print(m)
# Out:
# [-0.09947463]

# %%
c=lr.intercept_
print(c)
# Out:
# 3.346433142334239

# %%
m * 24 + c
# Out:
# array([0.95904201])

# %%
from sklearn.metrics import mean_absolute_error
#calculate Mean Absolute Error
mae=mean_absolute_error(y_test,y_predict)
print(f"Mean Absolute error:{mae:.2f}")
# Out:
# Mean Absolute error:0.30

# %%
from sklearn.metrics import mean_squared_error
#calculate nnMean squared error
mse=mean_squared_error(y_test,y_predict)
print(f"Mean Squared Error:{mse:.2f}")
# Out:
# Mean Squared Error:0.14
